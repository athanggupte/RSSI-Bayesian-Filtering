# %%
import pandas
import numpy as np
import math
import matplotlib.pyplot as plot

import import_ipynb
import Kalman_Filter
import Particle_Filter

print(dir(Kalman_Filter))
print(dir(Particle_Filter))
# Out:
# importing Jupyter notebook from Kalman_Filter.ipynb
# importing Jupyter notebook from Particle_Filter.ipynb
# ['__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'get_ipython', 'kalman', 'math', 'norm', 'np', 'predict', 'update']
# ['__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'estimate', 'generate_particles', 'get_ipython', 'math', 'neff', 'norm', 'np', 'particle_filter', 'plot', 'predict', 'random', 'resample', 'residual_resample', 'systematic_resample', 'update']

# %%
def data(file_name):
    rssi_data = pandas.read_csv(file_name).values.flatten()
    rssi_data = np.flip(rssi_data)
    return rssi_data

def distances(x0, rssi_data, n):
    n = 2.58
    e = (x0 - rssi_data)/(10*n)
    d = np.exp(math.log(10)*e)
    return d

# %%
x0 = -66.295
n = 2.58
actual_dist = 5
filename = 'RSSI-'+str(actual_dist)+'m.csv'
print('Reading file',filename,'...')
raw_rssi = data(filename)
raw_dist = distances(x0, raw_rssi, n)
axis = np.arange(0, raw_dist.size, 1)

#kf_rssi = Kalman_Filter.kalman(raw_rssi)
#kf_dist = distances(x0, kf_rssi, n)
kf_dist = Kalman_Filter.kalman(raw_dist)

pf_dist = Particle_Filter.particle_filter(raw_dist, 1000)

plot.ylabel('Distance')
plot.xlabel('Time')
#plot.ylim(0., 3.)
plot.plot(axis, raw_dist, label='Raw')
plot.plot(axis, kf_dist, label='KF')
plot.plot(axis, pf_dist, label='PF')
plot.legend()
plot.savefig('dist-time-'+str(actual_dist)+'m.png')
plot.pause(0.01)

print('mean:','\tRaw=',np.mean(raw_dist),'\tKF=',np.mean(kf_dist),'\tPF=',np.mean(pf_dist))
print('STD:','\tRaw=',np.std(raw_dist),'\tKF=',np.std(kf_dist),'\tPF=',np.std(pf_dist))
#print('error:','\Raw=',np.average(actual_distance - ))

print('\nERROR characteristics ---')

raw_error = np.abs(actual_dist - raw_dist)
kf_error = np.abs(actual_dist - kf_dist)
pf_error = np.abs(actual_dist - pf_dist)

plot.ylabel('Abs. Error')
plot.xlabel('Time')
plot.ylim(0., 5.)
plot.plot(axis, raw_error, label='Raw')
plot.plot(axis, kf_error, label='KF')
plot.plot(axis, pf_error, label='PF')
plot.legend()
plot.savefig('error-time-'+str(actual_dist)+'m.png')
plot.pause(0.01)

print('mean:','\tRaw=',np.mean(raw_error),'\tKF=',np.mean(kf_error),'\tPF=',np.mean(pf_error))
print('STD:','\tRaw=',np.std(raw_error),'\tKF=',np.std(kf_error),'\tPF=',np.std(pf_error))
# Out:
# Reading file RSSI-5m.csv ...
# mean: 	Raw= 5.006118547450946 	KF= 4.599220586090477 	PF= 3.979635266154716
# STD: 	Raw= 1.9361321828898392 	KF= 0.8886781519521633 	PF= 0.7555569912906231
#
# ERROR characteristics ---
# mean: 	Raw= 1.6481668104473832 	KF= 0.8508840183126146 	PF= 1.0468828204477358
# STD: 	Raw= 1.0159682235111405 	KF= 0.4757829166236959 	PF= 0.7183640563215051

# %%
print('Efficiency Comparison ---')

from timeit import timeit

number = 50

# Kalman Filter
print("Testing Kalman Filter ...")
kf_error_array = []
kf_rel_error = []

kf_setup = '''
from __main__ import Kalman_Filter, data, np, kf_error_array, kf_rel_error, distances
rssi_data = [data('RSSI-1m.csv'),data('RSSI-2m.csv'),data('RSSI-3m.csv'),data('RSSI-5m.csv')]
dist_data = [distances(-66.295, rssi_data[0], 2.58), distances(-66.295, rssi_data[1], 2.58), distances(-66.295, rssi_data[2], 2.58), distances(-66.295, rssi_data[3], 2.58)]
actual_dist = [1,2,3,5]
'''
kf_stmt = '''
error = []
for i in range(len(dist_data)):
    mean = np.mean(Kalman_Filter.kalman(dist_data[i]))
    #print(mean)
    error.append(np.mean(np.abs(actual_dist[i] - mean)))
kf_error_array.append(error)
kf_rel_error.append(np.divide(error, actual_dist))
'''

kf_time = timeit(setup=kf_setup, stmt=kf_stmt, number=number)
print('time: ',kf_time)

kf_error_array = np.array(kf_error_array)
kf_rel_error = np.array(kf_rel_error)
#print('\nAbs. Error\n',kf_error_array)
#print('\nRel. Error\n',kf_rel_error)
print('mean: ',np.mean(kf_rel_error),'\tSTD: ','{:.6f}'.format(np.std(kf_rel_error)))

plot.ylabel('Abs. Error')
plot.xlabel('Iteration')
lines = plot.plot(kf_error_array)
lines[0].set_label('1m')
lines[1].set_label('2m')
lines[2].set_label('3m')
lines[3].set_label('5m')
plot.pause(0.01)

plot.ylabel('Rel. Error')
plot.xlabel('Iteration')
plot.plot(kf_rel_error)
plot.pause(0.01)
# Out:
# Efficiency Comparison ---
# Testing Kalman Filter ...
# time:  0.05690929999946093
# mean:  0.18404672535881017 	STD:  0.244991
# 4

# %%
print('Efficiency Comparison ---')

from timeit import timeit

number = 50

# Particle Filter
print("Testing Particle Filter ...")
pf_error_array = []
pf_rel_error = []

pf_setup = '''
from __main__ import Particle_Filter, data, np, pf_error_array, pf_rel_error, distances
rssi_data = [data('RSSI-1m.csv'),data('RSSI-2m.csv'),data('RSSI-3m.csv'),data('RSSI-5m.csv')]
dist_data = [distances(-66.295, rssi_data[0], 2.58), distances(-66.295, rssi_data[1], 2.58), distances(-66.295, rssi_data[2], 2.58), distances(-66.295, rssi_data[3], 2.58)]
actual_dist = [1,2,3,5]
'''
pf_stmt = '''
error = []
for i in range(len(dist_data)):
    mean = np.mean(Particle_Filter.particle_filter(dist_data[i], enable_neffing=True))
    #print(mean)
    error.append(np.mean(np.abs(actual_dist[i] - mean)))
pf_error_array.append(error)
pf_rel_error.append(np.divide(error, actual_dist))
'''

pf_time = timeit(setup=pf_setup, stmt=pf_stmt, number=number)
print('time: ',pf_time)

pf_error_array = np.array(pf_error_array)
pf_rel_error = np.array(pf_rel_error)
#print('\nAbs. Error\n',kf_error_array)
#print('\nRel. Error\n',kf_rel_error)
print('mean: ',np.mean(pf_rel_error),'\tSTD: ','{:.6f}'.format(np.std(pf_rel_error)))

plot.ylabel('Abs. Error')
plot.xlabel('Iteration')
lines = plot.plot(pf_error_array)
print(len(lines))
plot.pause(0.01)

plot.ylabel('Rel. Error')
plot.xlabel('Iteration')
plot.plot(pf_rel_error)
plot.pause(0.01)
# Out:
# Efficiency Comparison ---
# Testing Particle Filter ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-201-375a8462d156> in <module>
#      26 '''
#      27
# ---> 28 pf_time = timeit(setup=pf_setup, stmt=pf_stmt, number=number)
#      29 print('time: ',pf_time)
#      30
#
# e:\python\lib\timeit.py in timeit(stmt, setup, timer, number, globals)
#     230            number=default_number, globals=None):
#     231     """Convenience function to create Timer object and call timeit method."""
# --> 232     return Timer(stmt, setup, timer, globals).timeit(number)
#     233
#     234 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# e:\python\lib\timeit.py in timeit(self, number)
#     174         gc.disable()
#     175         try:
# --> 176             timing = self.inner(it, self.timer)
#     177         finally:
#     178             if gcold:
#
# e:\python\lib\timeit.py in inner(_it, _timer)
#
# E:\Athang_Work\STC\impl\Particle_Filter.ipynb in particle_filter(distances, numParticles, enable_neffing, enable_intermediate_plotting)
#
# E:\Athang_Work\STC\impl\Particle_Filter.ipynb in predict(particles, process_std)
#
# KeyboardInterrupt:

# %%
print('Efficiency Comparison ---')

from timeit import timeit

number = 50

# Kalman Filter
print("Testing Kalman Filter ...")
kf_dist_array = []

kf_setup = '''
from __main__ import Kalman_Filter, raw_dist, np, kf_dist_array
'''
kf_stmt = '''kf_dist_array.append(np.mean(Kalman_Filter.kalman(raw_dist)))'''

kf_time = timeit(setup=kf_setup, stmt=kf_stmt, number=number)
print('time: ',kf_time)

kf_dist_array = np.array(kf_dist_array)
print('mean: ',np.mean(kf_dist_array),'\tSTD: ','{:.6f}'.format(np.std(kf_dist_array)))

plot.ylabel('Mean Distance')
plot.xlabel('Iteration')
plot.ylim(np.mean(kf_dist_array) - 1., np.mean(kf_dist_array) + 1)
plot.plot(kf_dist_array)
plot.pause(0.01)

# Particle Filter
print("Testing Particle Filter ...")
pf_dist_array = []

pf_setup = '''from __main__ import Particle_Filter, raw_dist, np, pf_dist_array'''
pf_stmt = '''pf_dist_array.append(np.mean(Particle_Filter.particle_filter(raw_dist)))'''

pf_time = timeit(setup=pf_setup, stmt=pf_stmt, number=number)
print('time: ',pf_time)

pf_dist_array = np.array(pf_dist_array)
print('mean: ',np.mean(pf_dist_array),'\tSTD: ','{:.6f}'.format(np.std(pf_dist_array)))

plot.ylabel('Mean Distance')
plot.xlabel('Iteration')
plot.ylim(np.mean(pf_dist_array) - 1., np.mean(pf_dist_array) + 1)
plot.plot(pf_dist_array)
plot.pause(0.01)
# Out:
# Efficiency Comparison ---
# Testing Kalman Filter ...
# time:  0.01230230000010124
# mean:  3.213112227942158 	STD:  0.000000
# Testing Particle Filter ...
# time:  8.54085299999997
# mean:  3.2326197753706007 	STD:  0.004459
